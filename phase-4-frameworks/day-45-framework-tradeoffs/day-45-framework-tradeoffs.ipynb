# %% [markdown]
# # Day 45 — Framework trade-offs
#
# There's no "best" — only fit. A rough guide:
#
# | Need | Reach for |
# | --- | --- |
# | Quick agent + tools, OpenAI-first | OpenAI Agents SDK |
# | Explicit control flow, branching, loops | LangGraph |
# | .NET / enterprise / plugins | Semantic Kernel |
# | Conversational multi-agent teams | AutoGen |
# | Tools as a reusable server | MCP |
#
# > ✅ Offline — a decision exercise.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
def recommend(need: str) -> str:
    # TODO: return a framework name for each need below.
    table = {
        "branching control flow": "____",      # LangGraph
        "openai-first quick agent": "____",     # OpenAI Agents SDK
        "conversational team": "____",          # AutoGen
        "reusable tool server": "____",         # MCP
    }
    return table.get(need, "it depends")

# for n in ["branching control flow", "conversational team"]:
#     print(n, "->", recommend(n))

# %% [markdown]
# ## 🔒 Solution
#
# Idiomatic, current-API version.

# %%
def recommend(need: str) -> str:
    table = {
        "branching control flow": "LangGraph",
        "openai-first quick agent": "OpenAI Agents SDK",
        "conversational team": "AutoGen",
        "reusable tool server": "MCP",
    }
    return table.get(need, "it depends")

for n in ["branching control flow", "openai-first quick agent", "conversational team", "reusable tool server"]:
    print(f"{n:28} -> {recommend(n)}")
