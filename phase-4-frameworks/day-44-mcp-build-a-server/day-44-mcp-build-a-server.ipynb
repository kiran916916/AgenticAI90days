# %% [markdown]
# # Day 44 — MCP II: build a server
#
# `FastMCP` makes a server trivial: decorate functions with `@mcp.tool()`. Run it with
# `mcp.run()` (stdio) and any MCP client can call your tools.
#
# ```bash
# pip install mcp
# ```
# > Defining tools runs offline; serving needs a client to connect.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib

root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)
# Out:
# repo root on sys.path: c:\autogen\AILearning

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
import asyncio
from mcp.server.fastmcp import FastMCP

mcp = FastMCP("demo")

@mcp.tool()
def add(a: int, b: int) -> int:
    return a + b

@mcp.tool()
def echo(text: str) -> str:
    return text

# To serve over stdio you would call:  mcp.run()
# TODO: list the registered tools (await mcp.list_tools()) and print their names.
async def show():
    tools = await mcp.list_tools()
    return [t.name for t in tools]

# print(await show())

# %% [markdown]
# ## 🔒 Solution
#
# Idiomatic, current-API version.

# %%
import asyncio
from mcp.server.fastmcp import FastMCP

mcp = FastMCP("demo")

@mcp.tool()
def add(a: int, b: int) -> int:
    return a + b

@mcp.tool()
def echo(text: str) -> str:
    return text

async def show():
    tools = await mcp.list_tools()
    return [t.name for t in tools]

print("registered tools:", await show())
print("Serve it for real with:  mcp.run()")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import asyncio
# ----> 2 from mcp.server.fastmcp import FastMCP
#       3
#       4 mcp = FastMCP("demo")
#       5
#
# ModuleNotFoundError: No module named 'mcp'
