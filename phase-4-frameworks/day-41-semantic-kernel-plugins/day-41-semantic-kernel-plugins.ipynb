# %% [markdown]
# # Day 41 — Semantic Kernel I: plugins
#
# In Semantic Kernel, tools are **plugins** — classes whose methods are decorated with
# `@kernel_function`. You can invoke them directly through the `Kernel` (no model needed),
# which is how SK marshals the model's function calls tomorrow.
#
# ```bash
# pip install semantic-kernel
# ```
# > ✅ Invoking a native function runs offline (no API key).

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
import asyncio
from typing import Annotated
from semantic_kernel import Kernel
from semantic_kernel.functions import kernel_function

class MathPlugin:
    @kernel_function(name="add", description="Add two integers")
    def add(self, a: Annotated[int, "first"], b: Annotated[int, "second"]) -> str:
        return str(int(a) + int(b))

async def main():
    kernel = Kernel()
    kernel.add_plugin(MathPlugin(), plugin_name="math")
    # TODO: result = await kernel.invoke(plugin_name="math", function_name="add", a=2, b=3)
    #       return result
    raise NotImplementedError

# In a notebook, call an async function with top-level await:
# print(await main())

# %% [markdown]
# ## 🔒 Solution
#
# Idiomatic, current-API version.

# %%
import asyncio
from typing import Annotated
from semantic_kernel import Kernel
from semantic_kernel.functions import kernel_function

class MathPlugin:
    @kernel_function(name="add", description="Add two integers")
    def add(self, a: Annotated[int, "first"], b: Annotated[int, "second"]) -> str:
        return str(int(a) + int(b))

async def main():
    kernel = Kernel()
    kernel.add_plugin(MathPlugin(), plugin_name="math")
    result = await kernel.invoke(plugin_name="math", function_name="add", a=2, b=3)
    return result

# Notebooks support top-level await directly:
print(await main())
