# %% [markdown]
# # Day 38 — LangChain core (LCEL)
#
# LangChain's expression language pipes components with `|`: **prompt → model → parser**.
# It's the most common way you'll see "a chain" written.
#
# ```bash
# pip install langchain langchain-openai
# ```
# > Needs `OPENAI_API_KEY`. Docs: https://python.langchain.com/

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are terse. Answer in one line."),
    ("human", "{question}"),
])
model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# TODO: chain = prompt | model | StrOutputParser()
#       print(chain.invoke({"question": "Name three primary colors."}))

# %% [markdown]
# ## 🔒 Solution
#
# Idiomatic, current-API version.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are terse. Answer in one line."),
    ("human", "{question}"),
])
model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

chain = prompt | model | StrOutputParser()
print(chain.invoke({"question": "Name three primary colors."}))
