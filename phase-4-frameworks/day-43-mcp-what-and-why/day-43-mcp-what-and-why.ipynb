# %% [markdown]
# # Day 43 — MCP I: what & why
#
# The **Model Context Protocol** standardizes how agents discover and call tools that live
# in a separate **server** process. Write a tool once; any MCP-aware client (Claude, VS Code,
# your agent) can use it. Today: understand the shape of an MCP tool.
#
# > ✅ Offline — a schema exercise. Tomorrow you build a real server.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
# An MCP tool advertises a name, description, and JSON input schema.
add_tool = {
    "name": "add",
    "description": "Add two integers",
    "inputSchema": {
        "type": "object",
        "properties": {"a": {"type": "integer"}, "b": {"type": "integer"}},
        "required": ["a", "b"],
    },
}
# TODO: write a second tool schema `echo_tool` that takes one string field `text`.
echo_tool = None

import json
for t in [add_tool, echo_tool]:
    print(json.dumps(t, indent=2) if t else "TODO: define echo_tool")

# %% [markdown]
# ## 🔒 Solution
#
# Idiomatic, current-API version.

# %%
import json

add_tool = {
    "name": "add",
    "description": "Add two integers",
    "inputSchema": {
        "type": "object",
        "properties": {"a": {"type": "integer"}, "b": {"type": "integer"}},
        "required": ["a", "b"],
    },
}
echo_tool = {
    "name": "echo",
    "description": "Echo the input text back",
    "inputSchema": {
        "type": "object",
        "properties": {"text": {"type": "string"}},
        "required": ["text"],
    },
}
for t in [add_tool, echo_tool]:
    print(json.dumps(t, indent=2))
