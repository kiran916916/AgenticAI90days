# %% [markdown]
# # Day 35 — Why frameworks? (map to your code)
#
# You already built the loop, tools, memory, and reflection by hand. Frameworks just give
# those parts **names, plumbing, and ecosystem**. Knowing the mapping means you can read
# *any* of them:
#
# | You built (Phase 2-3) | OpenAI Agents SDK | LangGraph | Semantic Kernel | AutoGen |
# | --- | --- | --- | --- | --- |
# | the agent loop | `Runner` | the graph | `kernel.invoke` | the team's chat |
# | a tool function | `@function_tool` | a node | `@kernel_function` | a `tool` |
# | your `Agent` class | `Agent` | `StateGraph` | `Kernel` | `AssistantAgent` |
# | handoff (Phase 6) | `handoffs=[...]` | edges | — | group chat |
#
# > ✅ Offline — this is a concept + mapping exercise.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
# Map each capability you built to the framework feature that provides it.
mapping = {
    "agent loop": "____",          # OpenAI Agents SDK class that runs the loop
    "tool function": "____",       # decorator in the OpenAI Agents SDK
    "graph of steps": "____",      # LangGraph core class
}
# TODO: fill the blanks with: "Runner", "@function_tool", "StateGraph"
for k, v in mapping.items():
    print(f"{k:16} -> {v}")

# %% [markdown]
# ## 🔒 Solution
#
# Idiomatic, current-API version.

# %%
mapping = {
    "agent loop": "Runner",
    "tool function": "@function_tool",
    "graph of steps": "StateGraph",
}
for k, v in mapping.items():
    print(f"{k:16} -> {v}")
print("\nSame ideas you already coded — just different names.")
