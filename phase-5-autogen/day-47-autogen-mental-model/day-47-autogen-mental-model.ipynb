# %% [markdown]
# # Day 47 — AutoGen mental model
#
# **AutoGen** (Microsoft) frames problem-solving as a **conversation between agents**. You
# already built every piece by hand — AutoGen names them:
#
# | You built | AutoGen |
# | --- | --- |
# | the agent loop | the team's chat |
# | your `Agent` class | `AssistantAgent` |
# | a tool function | a `tool` passed to the agent |
# | reflection / critic (Day 21) | a second agent in the chat |
# | human approval (Day 25) | `UserProxyAgent` |
#
# > ✅ Offline — a mapping exercise. The rest of the phase needs the install above.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
# Match each concept to its AutoGen name.
m = {
    "your Agent class": "____",     # AssistantAgent
    "human approval step": "____",  # UserProxyAgent
    "a turn-taking team": "____",   # RoundRobinGroupChat
}
# TODO: fill in: "AssistantAgent", "UserProxyAgent", "RoundRobinGroupChat"
for k, v in m.items():
    print(f"{k:22} -> {v}")

# %% [markdown]
# ## 🔒 Solution
#
# Verified against autogen-agentchat 0.7.5.

# %%
m = {
    "your Agent class": "AssistantAgent",
    "human approval step": "UserProxyAgent",
    "a turn-taking team": "RoundRobinGroupChat",
}
for k, v in m.items():
    print(f"{k:22} -> {v}")
