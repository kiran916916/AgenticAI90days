# %% [markdown]
# # Day 49 — Tools in AutoGen
#
# Pass any typed Python function in `tools=[...]` and AutoGen exposes it to the model as a
# callable tool — the native function-calling loop, handled for you.
#
# > Install: `pip install "autogen-agentchat" "autogen-ext[openai]"` and set `OPENAI_API_KEY`. For a local model, pass `base_url=` + `model_info=` to the client.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient

def add(a: int, b: int) -> int:
    return a + b

model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")
agent = AssistantAgent("calc", model_client=model_client, tools=[add],
                       system_message="Use your tools for arithmetic; reply with just the number.")

# TODO:
# result = await agent.run(task="What is 40 + 2?")
# print(result.messages[-1].content)
# await model_client.close()

# %% [markdown]
# ## 🔒 Solution
#
# Verified against autogen-agentchat 0.7.5.

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient

def add(a: int, b: int) -> int:
    return a + b

model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")
agent = AssistantAgent("calc", model_client=model_client, tools=[add],
                       system_message="Use your tools for arithmetic; reply with just the number.")

result = await agent.run(task="What is 40 + 2?")
print(result.messages[-1].content)
await model_client.close()
