# %% [markdown]
# # Day 70 — Embeddings at scale
#
# An **embedding** maps text to a vector so similar meanings sit close together. Here's a
# tiny deterministic embedder (bag-of-words hashing) so you can experiment offline; in
# production use [`shared.embed`](../../shared/llm.py). > ✅ Offline.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
import hashlib, math

def cheap_embed(text, dim=64):
    vec = [0.0] * dim
    for tok in text.lower().split():
        h = int(hashlib.md5(tok.encode()).hexdigest(), 16)
        vec[h % dim] += 1.0
    # TODO: L2-normalize the vector (divide by its length) and return it
    raise NotImplementedError

# v = cheap_embed("agents act in a loop")
# print("dim", len(v), "norm", round(sum(x*x for x in v) ** 0.5, 3))

# %% [markdown]
# ## 🔒 Solution

# %%
import hashlib, math

def cheap_embed(text, dim=64):
    vec = [0.0] * dim
    for tok in text.lower().split():
        h = int(hashlib.md5(tok.encode()).hexdigest(), 16)
        vec[h % dim] += 1.0
    norm = math.sqrt(sum(x * x for x in vec)) or 1.0
    return [x / norm for x in vec]

v = cheap_embed("agents act in a loop")
print("dim", len(v), "norm", round(sum(x * x for x in v) ** 0.5, 3))
