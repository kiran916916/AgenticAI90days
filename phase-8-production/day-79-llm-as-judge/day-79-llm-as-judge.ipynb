# %% [markdown]
# # Day 79 — LLM-as-judge
#
# For open-ended answers there's no exact string to match — so use a **model as grader**
# against criteria. Use sparingly (it costs tokens and can be biased). Uses
# [`shared.evals.llm_judge`](../../shared/evals.py). > Needs a provider.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
from shared.evals import llm_judge

question = "Explain what an API is in one sentence."
answer = "An API is a contract that lets two programs talk to each other."
criteria = "mentions that it lets software/programs communicate; one sentence"

# TODO: score, reason = llm_judge(question, answer, criteria)
#       print(score, reason)

# %% [markdown]
# ## 🔒 Solution

# %%
from shared.evals import llm_judge

question = "Explain what an API is in one sentence."
answer = "An API is a contract that lets two programs talk to each other."
criteria = "mentions that it lets software/programs communicate; one sentence"

score, reason = llm_judge(question, answer, criteria)
print(f"score {score}: {reason}")
