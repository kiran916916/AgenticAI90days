# %% [markdown]
# # Day 84 — Cost & latency budgets
#
# Every production agent needs a hard ceiling on **tokens** and **time**. Track spend and
# stop cleanly when the budget is exhausted — don't let a loop run up a bill. > ✅ Offline.

# %%
# ▶ Run this first — puts the repo root on sys.path so `shared/` imports work.
import sys, pathlib
root = pathlib.Path.cwd()
while root != root.parent and not (root / "shared" / "llm.py").exists():
    root = root.parent
if str(root) not in sys.path:
    sys.path.insert(0, str(root))
print("repo root on sys.path:", root)

# %% [markdown]
# ## 🔬 Your turn
#
# Fill in the `TODO`s, then run. Solution below.

# %%
class BudgetExceeded(RuntimeError):
    pass

class Budget:
    def __init__(self, max_tokens=1000):
        self.max_tokens = max_tokens
        self.used = 0
    def charge(self, tokens):
        # TODO: add tokens to self.used; if over max_tokens, raise BudgetExceeded; else return remaining
        raise NotImplementedError

# b = Budget(max_tokens=100)
# print(b.charge(60)); print(b.charge(30))
# try: b.charge(50)
# except BudgetExceeded as e: print("stopped:", e)

# %% [markdown]
# ## 🔒 Solution

# %%
class BudgetExceeded(RuntimeError):
    pass

class Budget:
    def __init__(self, max_tokens=1000):
        self.max_tokens = max_tokens
        self.used = 0
    def charge(self, tokens):
        self.used += tokens
        if self.used > self.max_tokens:
            raise BudgetExceeded(f"{self.used}/{self.max_tokens} tokens")
        return self.max_tokens - self.used

b = Budget(max_tokens=100)
print("remaining:", b.charge(60))
print("remaining:", b.charge(30))
try:
    b.charge(50)
except BudgetExceeded as e:
    print("stopped:", e)
